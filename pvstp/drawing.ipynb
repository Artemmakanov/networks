# %%
from utils import *
from model import *

# %%
vlans_n = 2
nets, c1s, d1s = find_convergence(10, 10, 100, vlans_n, rstp=True, verbose=True)
# Out:
#   7%|▋         | 7/100 [00:00<00:00, 4124.19it/s]
# STOPPED! at 7
#   7%|▋         | 7/100 [00:00<00:00, 3097.71it/s]
# STOPPED! at 7

# %%
draw_stp(nets, 'test-3', 15, vlans_n)

# %%
draw_stp(nets, 'test-cut-3', 35, vlans_n, broke_times=c1s, edgeid=4)
