# %%
from utils import *
from model import *

# %%
net, convergence, dim = find_convergence(9, 30, 100, verbose=True, mystp=True, rstp=True)
# Out:
# ...
#   4%|▍         | 4/100 [00:00<00:00, 1336.19it/s]
# STOPPED! at 4

# %%
draw_stp(net, 'test-3', 15)

# %%
draw_stp(net, 'test-cut-3', 40, broke_time=convergence+1, edgeid=4)
