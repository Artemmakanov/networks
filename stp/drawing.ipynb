# %%
from utils import *
from model import *

# %%
# find_convergence(количество node, количество edge, max_simul_steps, verbose=True, mystp=True, rstp=True)
# rstp - включить режим rstp, иначе - vanilla STP
# mystp - если True, то включается моя модифиция STP, когда порт переходит из состояния blocked
# не дожидаясь определения root bridge
net, convergence, dim = find_convergence(9, 15, 100, verbose=True, mystp=False, rstp=True)
# Out:
# ...
#   6%|▌         | 6/100 [00:00<00:00, 3963.75it/s]
# STOPPED! at 6

# %%
# Вершины помечаются как 
# bid
# root bid
# rpc
draw_stp(net, 'test-3', 15)

# %%
# Если broke_time не равен None, то заускается симуляция до того момента, когда не наступает
# момент broke_time (логично его задать как convergence+1)
# И рвется линк по номером edgeid (можно также задать линк через bid1 и bid2).
# Затем симуляция длиться до max_step
# Сломанный линк помечается черным цветом
max_step = 40
draw_stp(net, 'test-cut-3', max_step, broke_time=convergence+1, edgeid=1)
